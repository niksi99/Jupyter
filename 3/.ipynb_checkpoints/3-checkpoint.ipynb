# %%
import pandas as pd

# %%
df = pd.read_csv("./file.csv")

# %%
df
# Out:
#        stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0       1/2/2005      1:55           NaN             M          1985.0
# 1      1/18/2005      8:15           NaN             M          1965.0
# 2      1/23/2005     23:15           NaN             M          1972.0
# 3      2/20/2005     17:15           NaN             M          1986.0
# 4      3/14/2005     10:00           NaN             F          1984.0
# ...          ...       ...           ...           ...             ...
# 65530  12/6/2012     17:54           NaN             F          1987.0
# 65531  12/6/2012     22:22           NaN             M          1954.0
# 65532  12/6/2012     23:20           NaN             M          1985.0
# 65533  12/7/2012      0:23           NaN           NaN             NaN
# 65534  12/7/2012      0:30           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# ...

# %% [markdown]
# ### 1) Instruction ( For Data Cleaning ) - Remove the column that only contains missing values.

# %%
df.isna().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name          65535
# driver_gender          4061
# driver_age_raw         4054
# driver_age             4307
# driver_race            4060
# violation_raw          4060
# violation              4060
# search_conducted          0
# search_type           63056
# stop_outcome           4060
# is_arrested            4060
# stop_duration          4060
# drugs_related_stop        0
# dtype: int64

# %%
df.drop(columns = "country_name", inplace=True)

# %%
df
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %% [markdown]
# ### 2.Question ( Based on Filtering + Value Counts ) - For Speeding , were Men or Women stopped more often ?

# %%
df.groupby("driver_gender")#[ (df["violation"].str.contains("Speeding")) | (df["violation_raw"].str.contains("Speeding"))]

# %%
##df.loc[df["violation"].str.contains("Speeding")]#| (df["violation_raw"].str.contains("Speeding"))]]

# %%
df[df["violation"] == "Speeding"].driver_gender.value_counts()
# Out:
# driver_gender
# M    25517
# F    11686
# Name: count, dtype: int64

# %% [markdown]
# ### 3) 3) Question ( Groupby ) - Does gender affect who gets searched during a stop ?

# %%
df.groupby("driver_gender").search_conducted.count()
# Out:
# driver_gender
# F    16310
# M    45164
# Name: search_conducted, dtype: int64

# %% [markdown]
# ### 4)Question ( mapping + data-type casting ) - What is the mean stop_duration ?

# %%
df["stop_duration"] = df["stop_duration"].map({"0-15 Min":7.5, "16-30 Min":15, "30+ Min": 22})

# %%
df["stop_duration"].mean()
# Out:
# 9.521041415883138

# %%
df.groupby("driver_age").violation.describe()
# Out:
#            count unique               top  freq
# driver_age
# 15.0           5      2  Moving violation     4
# 16.0          34      5          Speeding    18
# 17.0         449      5          Speeding   338
# 18.0        1344      5          Speeding   980
# 19.0        2388      5          Speeding  1655
# ...          ...    ...               ...   ...
# 83.0           2      2          Speeding     1
# 84.0           3      1          Speeding     3
# 85.0           1      1  Moving violation     1
# 86.0           6      3          Speeding     3
# 88.0           2      1          Speeding     2
#
# [73 rows x 4 columns]

# %%
df.groupby("violation").driver_age.describe()
# Out:
#                        count       mean        std   min   25%   50%   75%  \
# violation
# Equipment             6507.0  31.682957  11.380671  16.0  23.0  28.0  39.0
# Moving violation     11876.0  36.736443  13.258350  15.0  25.0  35.0  47.0
# Other                 3477.0  40.362381  12.754423  16.0  30.0  41.0  50.0
# Registration/plates   2240.0  32.656696  11.150780  16.0  24.0  30.0  40.0
# Seat belt                3.0  30.333333  10.214369  23.0  24.5  26.0  34.0
# Speeding             37120.0  33.262581  12.615781  15.0  23.0  30.0  42.0
#
#                       max
# violation
# Equipment            81.0
# Moving violation     86.0
# Other                86.0
# Registration/plates  74.0
# Seat belt            42.0
# Speeding             88.0
