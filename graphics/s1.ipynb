# %%
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
sbn.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
mpg = sbn.load_dataset("mpg")

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %% [markdown]
# ### Introduction

# %%
sbn.set_theme()

# %%
sbn.set_style("darkgrid")

# %%
sbn.set_context("paper")

# %%
sbn.scatterplot(data=mpg, x="weight", y="mpg")
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %%
a = mpg.corr(numeric_only=True)
a
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.689196   -0.416361
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %%
sbn.heatmap(a)
# Out:
# <Axes: >

# %% [markdown]
# ### Scatterplot

# %%
plt.figure(figsize=(10, 7))
sbn.scatterplot(data=mpg, x="weight", y="mpg", hue="origin", palette="magma")
#sbn.despine(left=True)
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %% [markdown]
# ### Line

# %%
sbn.lineplot(data=mpg, x="model_year", y="weight")
# Out:
# <Axes: xlabel='model_year', ylabel='weight'>

# %% [markdown]
# ### Point plot

# %%
sbn.pointplot(data=mpg, x="model_year", y="weight")
# Out:
# <Axes: xlabel='model_year', ylabel='weight'>

# %% [markdown]
# ### KDEPLOT

# %%
sbn.kdeplot(data=mpg, x="model_year", y="mpg", fill=True)
# Out:
# <Axes: xlabel='model_year', ylabel='mpg'>

# %%
sbn.kdeplot(data=mpg, x="model_year")
# Out:
# <Axes: xlabel='model_year', ylabel='Density'>

# %% [markdown]
# ### HistPlot

# %%
sbn.histplot(data=mpg, x="weight", y="mpg")
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %%
sbn.histplot(data=mpg, x="weight", kde=True)
# Out:
# <Axes: xlabel='weight', ylabel='Count'>

# %% [markdown]
# ### ECDPLOT

# %%
sbn.ecdfplot(data=mpg, x="model_year")
# Out:
# <Axes: xlabel='model_year', ylabel='Proportion'>

# %% [markdown]
# ### COUNTPLOT

# %%
sbn.countplot(data=mpg, x="model_year")
# Out:
# <Axes: xlabel='model_year', ylabel='count'>

# %% [markdown]
# ### Barplot

# %%
sbn.barplot(data=mpg, x="origin", y="mpg")
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %% [markdown]
# ### Boxplot

# %%
sbn.boxplot(data=mpg, x="origin", y="mpg")
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %% [markdown]
# ### boxen plot

# %%
sbn.boxenplot(data=mpg, x="origin", y="mpg")
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %% [markdown]
# ### violin plot

# %%
sbn.violinplot(data=mpg, x="origin", y="mpg")
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>
